# %% [markdown]
# # **Course:** Introduction to Computer Vision (CS231.Q11)
#
# **Topic:** Face Mask Classification
#
# **Member:**
# - Nguyen Cong Phat - 23521143
# - Nguyen Le Phong - 23521168
# - Vu Viet Cuong - 23520213

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: colorama in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\nguyencongphat\appdata\local\programs\python\python311\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## **1. Imports & config**

# %%
import os
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

from skimage.io import imread
from skimage.color import rgb2gray
from skimage.transform import resize
from skimage.feature import hog

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

import seaborn as sns
from tqdm import tqdm
import joblib

# %%
DATA_DIR = Path("D:/UIT/HK1_25-26/CS231.Q11NhapMonCV/DoAn/Face Mask Dataset")  

SPLITS = ["Train", "Validation", "Test"]
CLASSES = ["WithMask", "WithoutMask"]

IMAGE_SIZE = (128, 128)

# HOG 6x3
HOG_PARAMS = {
    "orientations": 9,
    "pixels_per_cell": (6, 6),
    "cells_per_block": (3, 3),
    "block_norm": "L2-Hys"
}

CACHE_DIR = Path("cache")
CACHE_DIR.mkdir(exist_ok=True, parents=True)

MODELS_DIR = Path("D:/UIT/HK1_25-26/CS231.Q11NhapMonCV/DoAn/CS231Project/models")  # lưu model chung ở ngoài
MODELS_DIR.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ## **2. Load image paths & basic stats**

# %%
def load_split_paths(split: str):
    """
    Trả về list đường dẫn ảnh và nhãn tương ứng
    cho split: Train / Validation / Test
    """
    paths = []
    labels = []
    split_dir = DATA_DIR / split
    for cls in CLASSES:
        class_dir = split_dir / cls
        for img_path in sorted(class_dir.glob("*.*")):
            paths.append(img_path)
            labels.append(cls)
    return np.array(paths), np.array(labels)

all_stats = {}

for split in SPLITS:
    paths, labels = load_split_paths(split)
    unique, counts = np.unique(labels, return_counts=True)
    stats = dict(zip(unique, counts))
    all_stats[split] = stats

all_stats
# Out:
# {'Train': {'WithMask': 5000, 'WithoutMask': 5000},
#  'Validation': {'WithMask': 400, 'WithoutMask': 400},
#  'Test': {'WithMask': 483, 'WithoutMask': 509}}

# %% [markdown]
# ## **3. Plot class distribution**

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
for i, split in enumerate(SPLITS):
    stats = all_stats[split]
    ax = axes[i]
    ax.bar(stats.keys(), stats.values())
    ax.set_title(split)
    ax.set_ylabel("Number of images")
    ax.set_xticklabels(stats.keys(), rotation=15)

plt.suptitle("Class distribution across splits")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\NguyenCongPhat\AppData\Local\Temp\ipykernel_30340\4110489579.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.keys(), rotation=15)
# C:\Users\NguyenCongPhat\AppData\Local\Temp\ipykernel_30340\4110489579.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.keys(), rotation=15)
# C:\Users\NguyenCongPhat\AppData\Local\Temp\ipykernel_30340\4110489579.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(stats.keys(), rotation=15)

# %% [markdown]
# ## **4. Show some sample images**

# %%
paths_train, labels_train = load_split_paths("Train")

plt.figure(figsize=(10, 5))
idxs = np.random.choice(len(paths_train), size=8, replace=False)
for i, idx in enumerate(idxs, 1):
    img = imread(paths_train[idx])
    plt.subplot(2, 4, i)
    if img.ndim == 2:
        plt.imshow(img, cmap="gray")
    else:
        plt.imshow(img)
    plt.axis("off")
    plt.title(labels_train[idx])
plt.suptitle("Sample training images")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. HOG feature extractor + visualize HOG for 1 image**

# %%
def extract_hog_feature(img_path: Path, hog_params: dict) -> np.ndarray:
    img = imread(img_path)
    if img.ndim == 3:
        img_gray = rgb2gray(img)
    else:
        img_gray = img

    img_resized = resize(img_gray, IMAGE_SIZE, anti_aliasing=True)
    feat = hog(img_resized, **hog_params)
    return feat


# visualize HOG
from skimage.feature import hog as hog_vis

sample_img_path = paths_train[0]
sample_img = imread(sample_img_path)
sample_gray = rgb2gray(sample_img) if sample_img.ndim == 3 else sample_img
sample_resized = resize(sample_gray, IMAGE_SIZE, anti_aliasing=True)

hog_feats, hog_image = hog_vis(sample_resized, visualize=True, **HOG_PARAMS)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_resized, cmap="gray")
plt.title("Resized")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(hog_image, cmap="gray")
plt.title("HOG Visualization (6x3)")
plt.axis("off")

plt.tight_layout()
plt.show()

print("HOG feature length:", hog_feats.size)
# Out:
# HOG feature length: 29241

# %% [markdown]
# ## **6. Build & cache HOG features**

# %%
def get_hog_features(split: str):
    cache_file = CACHE_DIR / f"HOG_6x3_{split}.npz"

    if cache_file.exists():
        data = np.load(cache_file)
        print(f"[{split}] Loaded from cache")
        return data["X"], data["y"]

    print(f"[{split}] Extracting HOG features...")
    paths, labels = load_split_paths(split)

    feats = []
    for p in tqdm(paths):
        feats.append(extract_hog_feature(p, HOG_PARAMS))

    X = np.vstack(feats)
    y = labels
    np.savez_compressed(cache_file, X=X, y=y)
    print(f"[{split}] Saved to cache")
    return X, y


X_train, y_train = get_hog_features("Train")
X_val,   y_val   = get_hog_features("Validation")
X_test,  y_test  = get_hog_features("Test")

X_train.shape, X_val.shape, X_test.shape
# Out:
# [Train] Extracting HOG features...
# 100%|██████████| 10000/10000 [06:07<00:00, 27.18it/s]
# [Train] Saved to cache
# [Validation] Extracting HOG features...
# 100%|██████████| 800/800 [01:22<00:00,  9.72it/s]
# [Validation] Saved to cache
# [Test] Extracting HOG features...
# 100%|██████████| 992/992 [01:43<00:00,  9.60it/s]
# [Test] Saved to cache
# ((10000, 29241), (800, 29241), (992, 29241))

# %% [markdown]
# ## **7. Encode labels**

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_val_enc   = le.transform(y_val)
y_test_enc  = le.transform(y_test)

le.classes_, np.bincount(y_train_enc)
# Out:
# (array(['WithMask', 'WithoutMask'], dtype='<U11'),
#  array([5000, 5000], dtype=int64))

# %% [markdown]
# ## **8. Optuna + KNN (HOG 6x3)**

# %%
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler

from sklearn.neighbors import KNeighborsClassifier

def objective(trial):
    # Không gian tham số cho KNN
    params = {
        # số láng giềng, thử số lẻ 1–31 để tránh tie
        "n_neighbors": trial.suggest_int("n_neighbors", 1, 31, step=2),
        # uniform: mọi hàng xóm như nhau, distance: hàng xóm gần hơn trọng số lớn hơn
        "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
        # p = 1: Manhattan, p = 2: Euclidean
        "p": trial.suggest_int("p", 1, 2),
        # metric để mặc định minkowski (dùng chung với p)
        "metric": "minkowski",
    }

    clf = KNeighborsClassifier(**params)
    clf.fit(X_train, y_train_enc)

    y_val_pred = clf.predict(X_val)
    acc = accuracy_score(y_val_enc, y_val_pred)
    return acc


study_knn = optuna.create_study(
    direction="maximize",
    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=1),
    sampler=TPESampler(multivariate=True),
)

study_knn.optimize(objective, n_trials=30, n_jobs=1)  

print("[KNN] Best validation accuracy:", study_knn.best_value)
print("[KNN] Best params:", study_knn.best_params)
# Out:
# c:\Users\NguyenCongPhat\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2025-11-29 17:50:51,181] A new study created in memory with name: no-name-f97f9428-341c-43c5-9128-588a377d292e
# [I 2025-11-29 17:55:34,536] Trial 0 finished with value: 0.8725 and parameters: {'n_neighbors': 29, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8725.
# [I 2025-11-29 17:55:57,936] Trial 1 finished with value: 0.9625 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:00:24,448] Trial 2 finished with value: 0.89 and parameters: {'n_neighbors': 21, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:00:47,997] Trial 3 finished with value: 0.96125 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'p': 2}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:05:06,417] Trial 4 finished with value: 0.91375 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 1}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:09:34,851] Trial 5 finished with value: 0.89 and parameters: {'n_neighbors': 21, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:09:55,739] Trial 6 finished with value: 0.95 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:14:05,391] Trial 7 finished with value: 0.88 and parameters: {'n_neighbors': 25, 'weights': 'distance', 'p': 1}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:14:28,691] Trial 8 finished with value: 0.93875 and parameters: {'n_neighbors': 29, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:18:35,200] Trial 9 finished with value: 0.8975 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 1}. Best is trial 1 with value: 0.9625.
# [I 2025-11-29 18:18:58,714] Trial 10 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:19:22,252] Trial 11 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:23:48,320] Trial 12 finished with value: 0.95 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 1}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:24:11,714] Trial 13 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:24:39,475] Trial 14 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:25:03,049] Trial 15 finished with value: 0.95125 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:25:26,607] Trial 16 finished with value: 0.95875 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:25:49,848] Trial 17 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:30:16,869] Trial 18 finished with value: 0.905 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 1}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:30:28,202] Trial 19 finished with value: 0.9475 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:30:39,321] Trial 20 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:30:49,343] Trial 21 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:30:59,181] Trial 22 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:09,616] Trial 23 finished with value: 0.9525 and parameters: {'n_neighbors': 27, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:20,316] Trial 24 finished with value: 0.95125 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:29,547] Trial 25 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:39,444] Trial 26 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:49,256] Trial 27 finished with value: 0.95125 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:31:59,046] Trial 28 finished with value: 0.97125 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 0.97125.
# [I 2025-11-29 18:33:49,975] Trial 29 finished with value: 0.95 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.97125.
# [KNN] Best validation accuracy: 0.97125
# [KNN] Best params: {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}

# %% [markdown]
# ## **9. Refit best KNN on Train + Validation**

# %%
best_knn_params = study_knn.best_params.copy()

X_combined = np.vstack([X_train, X_val])
y_combined = np.concatenate([y_train_enc, y_val_enc])

best_knn = KNeighborsClassifier(**best_knn_params)
best_knn.fit(X_combined, y_combined)

print("Done training final KNN with Optuna best params.")
best_knn_params
# Out:
# Done training final KNN with Optuna best params.
# {'n_neighbors': 1, 'weights': 'uniform', 'p': 2}

# %% [markdown]
# ## **10. Evaluate on Test + confusion matrix + save KNN model**

# %%
y_test_pred_knn = best_knn.predict(X_test)

test_acc_knn = accuracy_score(y_test_enc, y_test_pred_knn)
print(f"Test Accuracy (HOG 6x3 + KNN Optuna): {test_acc_knn:.4f}\n")

print("Classification report (KNN):")
print(classification_report(y_test_enc, y_test_pred_knn, target_names=le.classes_))

cm_knn = confusion_matrix(y_test_enc, y_test_pred_knn)

plt.figure(figsize=(4, 4))
sns.heatmap(
    cm_knn,
    annot=True,
    fmt="d",
    xticklabels=le.classes_,
    yticklabels=le.classes_,
    cbar=False
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - HOG 6x3 + KNN (Optuna)")
plt.tight_layout()
plt.show()

# Lưu model + encoder + HOG params
model_path_knn = MODELS_DIR / "HOG_6x3_KNN_Optuna.joblib"

joblib.dump(
    {
        "model": best_knn,
        "label_encoder": le,
        "hog_params": HOG_PARAMS,
        "image_size": IMAGE_SIZE,
    },
    model_path_knn
)

print("KNN model saved to:", model_path_knn)
# Out:
# Test Accuracy (HOG 6x3 + KNN Optuna): 0.9748
#
# Classification report (KNN):
#               precision    recall  f1-score   support
#
#     WithMask       0.99      0.95      0.97       483
#  WithoutMask       0.96      0.99      0.98       509
#
#     accuracy                           0.97       992
#    macro avg       0.98      0.97      0.97       992
# weighted avg       0.98      0.97      0.97       992
# KNN model saved to: D:\UIT\HK1_25-26\CS231.Q11NhapMonCV\DoAn\CS231Project\models\HOG_6x3_KNN_Optuna.joblib
